# %%
import os
# Setting JAVA_HOME to Java 21 to avoid compatibility issues
os.environ["JAVA_HOME"] = "C:\\Program Files\\Java\\jdk-21"
# Pointing HADOOP_HOME to the project directory where we downloaded winutils.exe
os.environ["HADOOP_HOME"] = "l:\\pos-graduacao-engenharia-arquitetura-dados\\Hadoop"

# FORCE STOP EXISTING SPARK SESSIONS to ensure new config is applied
try:
    from pyspark.sql import SparkSession
    SparkSession.getActiveSession().stop()
    print("Sessão Spark anterior encerrada.")
except:
    pass
# Out:
# Sessão Spark anterior encerrada.

# %%
pip install "flask<2.3,>=2.2"
# Out:
# Requirement already satisfied: flask<2.3,>=2.2 in c:\python314\lib\site-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\python314\lib\site-packages (from flask<2.3,>=2.2) (3.1.5)
# Requirement already satisfied: Jinja2>=3.0 in c:\python314\lib\site-packages (from flask<2.3,>=2.2) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.0 in c:\python314\lib\site-packages (from flask<2.3,>=2.2) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\python314\lib\site-packages (from flask<2.3,>=2.2) (8.3.1)
# Requirement already satisfied: colorama in c:\python314\lib\site-packages (from click>=8.0->flask<2.3,>=2.2) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python314\lib\site-packages (from Jinja2>=3.0->flask<2.3,>=2.2) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\python314\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyspark boto3
# Out:
# Requirement already satisfied: pyspark in c:\python314\lib\site-packages (4.1.1)
# Requirement already satisfied: boto3 in c:\python314\lib\site-packages (1.42.41)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\python314\lib\site-packages (from pyspark) (0.10.9.9)
# Requirement already satisfied: botocore<1.43.0,>=1.42.41 in c:\python314\lib\site-packages (from boto3) (1.42.41)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\python314\lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\python314\lib\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\python314\lib\site-packages (from botocore<1.43.0,>=1.42.41->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\python314\lib\site-packages (from botocore<1.43.0,>=1.42.41->boto3) (2.6.3)
# Requirement already satisfied: six>=1.5 in c:\python314\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.41->boto3) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("S3 Access Example") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262") \
    .getOrCreate()
from pyspark.sql.functions import col, from_unixtime, avg, count
from dotenv import load_dotenv

# %%
# -----------------------
# 1. Carregar Variáveis de Ambiente do .env_kafka_connect
# -----------------------
load_dotenv('.env_kafka_connect')  # Carregar o arquivo .env

aws_access_key = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
aws_region = "us-east-1"

# %%
# -----------------------
# 2. Inicializar a Spark Session com Configuração S3
# -----------------------

# Caminho local dos arquivos JAR no mesmo diretório do notebook
# Obter caminho absoluto dos JARs
current_dir = os.getcwd()
hadoop_aws_jar = os.path.join(current_dir, "hadoop-aws-3.3.4.jar")
aws_sdk_jar = os.path.join(current_dir, "aws-java-sdk-bundle-1.12.262.jar")

jars_path = f"{hadoop_aws_jar},{aws_sdk_jar}"

spark = SparkSession.builder \
    .appName("ETL Pipeline - S3 Integration") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.jars", jars_path) \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .config("spark.default.parallelism", "8") \
    .config("spark.hadoop.fs.s3a.committer.name", "magic") \
    .config("spark.hadoop.fs.s3a.committer.magic.enabled", "true") \
    .config("spark.hadoop.fs.s3a.connection.timeout", "60000") \
    .config("spark.hadoop.fs.s3a.socket.timeout", "60000") \
    .config("spark.driver.extraJavaOptions", "-Dfs.s3a.connection.timeout=60000 -Dfs.s3a.socket.timeout=60000") \
    .getOrCreate()


# Configuração dinâmica das credenciais AWS no Spark
spark._jsc.hadoopConfiguration().set("fs.s3a.access.key", aws_access_key)
spark._jsc.hadoopConfiguration().set("fs.s3a.secret.key", aws_secret_key)
spark._jsc.hadoopConfiguration().set("fs.s3a.endpoint", f"s3.{aws_region}.amazonaws.com")

# Configuração do acesso ao S3
spark._jsc.hadoopConfiguration().set("fs.s3a.access.key", aws_access_key)
spark._jsc.hadoopConfiguration().set("fs.s3a.secret.key", aws_secret_key)
spark._jsc.hadoopConfiguration().set("fs.s3a.endpoint", f"s3.{aws_region}.amazonaws.com")
spark._jsc.hadoopConfiguration().set("fs.s3a.connection.ssl.enabled", "true")
spark._jsc.hadoopConfiguration().set("fs.s3a.path.style.access", "true")

# %%
# -----------------------
# 3. Ler os Dados Brutos - Camada Bronze
# não se esqueça de alterar o nome do seu bucket
# -----------------------

bronze_path = "s3a://desafio-bronze-cesteves/raw-data/ipca/kafka/"

# Ler os dados do S3 e testar a conexão
print(f"Lendo dados de: {bronze_path}")
df_bronze = spark.read.json(bronze_path)
print("Leitura bem-sucedida!")

# Otimização para TESTE: Processar apenas 100 registros para ser rápido e criar as pastas
print("Modo de TESTE: Limitando a 100 registros para criar pastas rapidamente.")
df_bronze = df_bronze.limit(100).coalesce(1)
df_bronze.printSchema()
df_bronze.show(5)
# Out:
# Lendo dados de: s3a://desafio-bronze-cesteves/raw-data/ipca/kafka/
# ---------------------------------------------------------------------------
# NumberFormatException                     Traceback (most recent call last)
# Cell In[16], line 10
#       8 # Ler os dados do S3 e testar a conexão
#       9 print(f"Lendo dados de: {bronze_path}")
# ---> 10 df_bronze = spark.read.json(bronze_path)
#      11 print("Leitura bem-sucedida!")
#      13 # Otimização para TESTE: Processar apenas 100 registros para ser rápido e criar as pastas
#
# File C:\Python314\Lib\site-packages\pyspark\sql\readwriter.py:468, in DataFrameReader.json(self, path, schema, primitivesAsString, prefersDecimal, allowComments, allowUnquotedFieldNames, allowSingleQuotes, allowNumericLeadingZero, allowBackslashEscapingAnyCharacter, mode, columnNameOfCorruptRecord, dateFormat, timestampFormat, multiLine, allowUnquotedControlChars, lineSep, samplingRatio, dropFieldIfAllNull, encoding, locale, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, allowNonNumericNumbers, useUnsafeRow)
#     466 if type(path) == list:
#     467     assert self._spark._sc._jvm is not None
# --> 468     return self._df(self._jreader.json(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     470 if not is_remote_only():
#     471     from pyspark.core.rdd import RDD  # noqa: F401
#
# File C:\Python314\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File C:\Python314\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# NumberFormatException: For input string: "60s"

# %%
# -----------------------
# 4. Tratamento dos Dados - Camada Silver
# -----------------------
# Remover duplicações e converter timestamps para datas legíveis
df_silver = df_bronze.dropDuplicates()

# Tratar timestamps e converter para formato legível
df_silver = df_silver.withColumn("Data_Vencimento", from_unixtime(col("Data_Vencimento") / 1000, "yyyy-MM-dd")) \
                     .withColumn("Data_Base", from_unixtime(col("Data_Base") / 1000, "yyyy-MM-dd")) \
                     .withColumn("dt_update", from_unixtime(col("dt_update") / 1000, "yyyy-MM-dd HH:mm:ss"))

# Tratar valores nulos
df_silver = df_silver.fillna({
    "PUCompraManha": 0,
    "PUVendaManha": 0,
    "PUBaseManha": 0
})

# Visualizar os dados transformados
print("Dados Transformados (Silver):")
df_silver.show(truncate=False)

# Salvar os dados limpos no S3 em formato Parquet
silver_path = "s3a://desafio-silver-gold-cesteves/processed-data/ipca/silver/"
df_silver.write.mode("overwrite").parquet(silver_path)

# %%
# -----------------------
# 5. Agregação e Métricas - Camada Gold
# -----------------------
# Calcular métricas agregadas
df_gold = df_silver.groupBy("Tipo").agg(
    avg("PUCompraManha").alias("Media_PUCompraManha"),
    avg("PUVendaManha").alias("Media_PUVendaManha"),
    count("*").alias("Total_Registros")
)

# Visualizar as métricas agregadas
print("Dados Agregados (Gold):")
df_gold.show(truncate=False)

# Salvar os dados agregados no S3 em formato Parquet
gold_path = "s3a://desafio-silver-gold-cesteves/analytics/ipca/gold/"
df_gold.write.mode("overwrite").parquet(gold_path)

# %%
# -----------------------
# 6. Encerrar a Spark Session
# -----------------------
spark.stop()
